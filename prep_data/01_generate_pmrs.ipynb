# %% [markdown]
# # Purpose
# The purpose of this code is to identify PMR from samples of DNA across many different cancers and test the algorithm

# %% [markdown]
# # Code

# %% [markdown]
# Tell ipython to reload modules so we can update other files

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from methylation_utils.methylation_utils.analyzer import (
    MethylationAnalyzer,
    MethylationAnalyzerHelper,
)
from methylation_utils.methylation_utils.plot import MethPlot, ChromIdeoPlot
from methylation_utils.methylation_utils.utils import compare_bed_dfs
from methylation_utils.generic_utils import instantiate_progress_bar
from pybedtools import BedTool
import pyarrow.feather as feather

# %%
INCLUDE_NORMAL_SAMPLES = False

# %% [markdown]
# ## Samples

# %%
SAMPLES_FILE = "data/old_data/runAll.sh.samples"
METH_DYNAMIC_FOLDER = "data/old_data/bottom/samples_meth_dynamic"
METH_REF_FILE = "data/old_data/parse450K.pl.order.lookup"

# %%
""" Read in the sample info and methylation reference into memory """
sample_info = pd.read_csv(SAMPLES_FILE,sep="\t")
print('Read ' + str(len(sample_info.index)) + ' samples')
meth_ref = pd.read_csv(METH_REF_FILE,sep="\t")
# Out:
# Read 9714 samples

# %%
meth_ref
# Out:
#                key CpG_chrm  CpG_beg  CpG_end probe_strand     probeID  \
# 0       cg13869341     chr1  15864.0  15866.0            -  cg13869341
# 1       cg14008030     chr1  18826.0  18828.0            -  cg14008030
# 2       cg12045430     chr1  29406.0  29408.0            -  cg12045430
# 3       cg20826792     chr1  29424.0  29426.0            -  cg20826792
# 4       cg00381604     chr1  29434.0  29436.0            -  cg00381604
# ...            ...      ...      ...      ...          ...         ...
# 485572  cg24238852      NaN      NaN      NaN            *  cg24238852
# 485573  cg15254640      NaN      NaN      NaN            *  cg15254640
# 485574  cg24336839      NaN      NaN      NaN            *  cg24336839
# 485575  cg11478607      NaN      NaN      NaN            *  cg11478607
# 485576  cg08417382      NaN      NaN      NaN            *  cg08417382
#
#                            genesUniq  \
# 0                             WASH7P
# 1                   MIR6859-1;WASH7P
# 2       MIR1302-2;MIR1302-2HG;WASH7P
# 3       MIR1302-2;MIR1302-2HG;WASH7P
# 4       MIR1302-2;MIR1302-2HG;WASH7P
# ...                              ...
# 485572                           NaN
# 485573                           NaN
# 485574                           NaN
# 485575                           NaN
# 485576                           NaN
#
#                                        geneNames  \
# 0                                         WASH7P
# 1                               MIR6859-1;WASH7P
# 2       MIR1302-2;MIR1302-2HG;MIR1302-2HG;WASH7P
# 3       MIR1302-2;MIR1302-2HG;MIR1302-2HG;WASH7P
# 4       MIR1302-2;MIR1302-2HG;MIR1302-2HG;WASH7P
# ...                                          ...
# 485572                                       NaN
# 485573                                       NaN
# 485574                                       NaN
# 485575                                       NaN
# 485576                                       NaN
#
#                                    transcriptTypes  \
# 0                           unprocessed_pseudogene
# 1                     miRNA;unprocessed_pseudogene
# 2       miRNA;lncRNA;lncRNA;unprocessed_pseudogene
# 3       miRNA;lncRNA;lncRNA;unprocessed_pseudogene
# 4       miRNA;lncRNA;lncRNA;unprocessed_pseudogene
# ...                                            ...
# 485572                                         NaN
# 485573                                         NaN
# 485574                                         NaN
# 485575                                         NaN
# 485576                                         NaN
#
#                                             transcriptIDs           distToTSS  \
# 0                                       ENST00000488147.1               13706
# 1                     ENST00000619216.1;ENST00000488147.1         -1390;10744
# 2       ENST00000607096.1;ENST00000469289.1;ENST000004...  -959;-860;-147;164
# 3       ENST00000607096.1;ENST00000469289.1;ENST000004...  -941;-842;-129;146
# 4       ENST00000607096.1;ENST00000469289.1;ENST000004...  -931;-832;-119;136
# ...                                                   ...                 ...
# 485572                                                NaN                 NaN
# 485573                                                NaN                 NaN
# 485574                                                NaN                 NaN
# 485575                                                NaN                 NaN
# 485576                                                NaN                 NaN
#
#                          CGI CGIposition
# 0                        NaN         NaN
# 1                        NaN         NaN
# 2       CGI:chr1:28735-29737      Island
# 3       CGI:chr1:28735-29737      Island
# 4       CGI:chr1:28735-29737      Island
# ...                      ...         ...
# 485572                   NaN         NaN
# 485573                   NaN         NaN
# 485574                   NaN         NaN
# 485575                   NaN         NaN
# 485576                   NaN         NaN
#
# [485577 rows x 13 columns]

# %%
sample_info
# Out:
#                 sample                                         expression  \
# 0     TCGA-EX-A1H6-01B  72ac3cfa-31f8-4371-867d-ab897b2b7cb9.rna_seq.a...
# 1     TCGA-C5-A7CM-01A  8d405837-5989-4de9-a19c-4f7af4af65d3.rna_seq.a...
# 2     TCGA-C5-A2M1-01A  35e5936c-9722-4a49-9bb3-5c244bd10b13.rna_seq.a...
# 3     TCGA-LP-A5U2-01A  0aa549e1-bb9a-4489-b815-1c22817100d8.rna_seq.a...
# 4     TCGA-EK-A3GK-01A  20e72530-f9cc-44d6-81f9-bb7c49f1f7e4.rna_seq.a...
# ...                ...                                                ...
# 9709  TCGA-E2-A15J-01A  723ed50c-2c78-4a3a-9f6e-9f9e8e264f6b.rna_seq.a...
# 9710  TCGA-B6-A40C-01A  32c15b29-da14-4eb5-8c86-39efc94319df.rna_seq.a...
# 9711  TCGA-BH-A0B3-11B  d920c232-82ae-48f9-98d1-b94bf4a45d8d.rna_seq.a...
# 9712  TCGA-E9-A1QZ-01A  0f168687-6f42-4d92-8f91-13efde785a0c.rna_seq.a...
# 9713  TCGA-S3-AA10-01A  df6af593-6a85-4f5f-8dbe-c32df5a85ef6.rna_seq.a...
#
#                                         expression_file  \
# 0     /uufs/chpc.utah.edu/common/home/clementm-group...
# 1     /uufs/chpc.utah.edu/common/home/clementm-group...
# 2     /uufs/chpc.utah.edu/common/home/clementm-group...
# 3     /uufs/chpc.utah.edu/common/home/clementm-group...
# 4     /uufs/chpc.utah.edu/common/home/clementm-group...
# ...                                                 ...
# 9709  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9710  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9711  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9712  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9713  /uufs/chpc.utah.edu/common/home/clementm-group...
#
#                                             methylation  \
# 0     b04fb3ae-1075-4e4c-b519-743dd948ae45.methylati...
# 1     d1efc9b7-7499-4f95-90bb-7613a42ce82f.methylati...
# 2     c56b4dcd-d498-4394-9fc9-a449647021b1.methylati...
# 3     e51138bf-5d5c-4b32-ad9a-d8b84c2e541f.methylati...
# 4     1d7814b0-8818-4fcb-87e7-fef883f7571f.methylati...
# ...                                                 ...
# 9709  0b7f6506-a464-4635-ae6b-2820a0ab5206.methylati...
# 9710  f9dd5273-22ef-46c9-a8ad-c501825d2f3e.methylati...
# 9711  b504445f-170c-44ce-8a84-70db6930397f.methylati...
# 9712  a26af0de-1dff-4345-adf2-d3794fd33a6d.methylati...
# 9713  6b70879c-ab6f-4ed2-9f19-57558b01d140.methylati...
#
#                                        methylation_file  \
# 0     /uufs/chpc.utah.edu/common/home/clementm-group...
# 1     /uufs/chpc.utah.edu/common/home/clementm-group...
# 2     /uufs/chpc.utah.edu/common/home/clementm-group...
# 3     /uufs/chpc.utah.edu/common/home/clementm-group...
# 4     /uufs/chpc.utah.edu/common/home/clementm-group...
# ...                                                 ...
# 9709  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9710  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9711  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9712  /uufs/chpc.utah.edu/common/home/clementm-group...
# 9713  /uufs/chpc.utah.edu/common/home/clementm-group...
#
#                                  sample_id project_id   composition  \
# 0     fe018d31-eee8-4335-96a1-95eceabfadf1  TCGA-CESC  Not Reported
# 1     fefa6b4c-243d-4544-accc-11515bbe516e  TCGA-CESC  Not Reported
# 2     065bb06f-5bb7-4f79-b374-97a3011f22ae  TCGA-CESC  Not Reported
# 3     cbdbe0d3-b3b3-4990-be3a-9af8360889d8  TCGA-CESC  Not Reported
# 4     f9371b06-c6e5-4363-bdaa-bd85f95a01c4  TCGA-CESC  Not Reported
# ...                                    ...        ...           ...
# 9709  6f68a61c-8aec-42d3-b225-22bc6da3e355  TCGA-BRCA  Not Reported
# 9710  e852c16b-cd36-4551-8cc5-8b59719ca987  TCGA-BRCA  Not Reported
# 9711  9a81af95-30f8-45b1-bbda-ca5c7a91c5c5  TCGA-BRCA  Not Reported
# 9712  ec76e770-ba6b-4294-a992-993183640ff8  TCGA-BRCA  Not Reported
# 9713  9c531ed5-e501-4cbf-9977-202dc1c5e623  TCGA-BRCA  Not Reported
#
#               sample_type   tissue_type tumor_descriptor  \
# 0           Primary Tumor  Not Reported     Not Reported
# 1           Primary Tumor  Not Reported     Not Reported
# 2           Primary Tumor  Not Reported     Not Reported
# 3           Primary Tumor  Not Reported     Not Reported
# 4           Primary Tumor  Not Reported     Not Reported
# ...                   ...           ...              ...
# 9709        Primary Tumor  Not Reported     Not Reported
# 9710        Primary Tumor  Not Reported     Not Reported
# 9711  Solid Tissue Normal  Not Reported     Not Reported
# 9712        Primary Tumor  Not Reported     Not Reported
# 9713        Primary Tumor  Not Reported     Not Reported
#
#                                      project_descriptor
# 0     Cervical squamous cell carcinoma and endocervi...
# 1     Cervical squamous cell carcinoma and endocervi...
# 2     Cervical squamous cell carcinoma and endocervi...
# 3     Cervical squamous cell carcinoma and endocervi...
# 4     Cervical squamous cell carcinoma and endocervi...
# ...                                                 ...
# 9709                          Breast invasive carcinoma
# 9710                          Breast invasive carcinoma
# 9711                          Breast invasive carcinoma
# 9712                          Breast invasive carcinoma
# 9713                          Breast invasive carcinoma
#
# [9714 rows x 12 columns]

# %%
cancer_samples = sample_info[sample_info.sample_type != "Solid Tissue Normal"]

# %%
cancer_samples.sample_type.unique()
# Out:
# array(['Primary Tumor', 'Additional - New Primary', 'Metastatic',
#        'Recurrent Tumor', 'Additional Metastatic',
#        'Recurrent Blood Derived Cancer - Bone Marrow',
#        'Primary Blood Derived Cancer - Bone Marrow',
#        'Primary Blood Derived Cancer - Peripheral Blood',
#        'Recurrent Blood Derived Cancer - Peripheral Blood'], dtype=object)

# %% [markdown]
# ## Known

# %%
# !wget https://zhouserver.research.chop.edu/GenomeAnnotation/hg38/PMD_coordinates_hg38.bed.gz -P files/

# %%
zhou_meth_data = pd.read_csv('files/PMD_coordinates_hg38.bed.gz', compression='gzip',sep="\t",header=None,names=['chrom','start','end','val','PMD','type'])

# %%
zho_common_pmds = []

current_chrom = None
for index, row in zhou_meth_data.iterrows():
    if row['type'] == "commonPMD":
        if current_chrom is None or current_chrom != row['chrom']:
            #Start new region
            current_chrom = row['chrom']
            zho_common_pmds.append([row['chrom'], row['start'], row['end']])
        else:
            zho_common_pmds[-1][-1] = row['end']
    else:
        current_chrom = None

# %%
zho_common_pmds_df = pd.DataFrame(zho_common_pmds, columns=['chrom','start','end'])
zho_common_pmds_df["length"] = zho_common_pmds_df["end"] - zho_common_pmds_df["start"]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Constants

# %%
DEBUG = False

""" For individual samples """
METH_INTERMEDIATE_HIGH_CUTOFF = 70
METH_INTERMEDIATE_LOW_CUTOFF = 20

""" For combined samples """
# Number of samples that need to have intermediate methylation at a site for the site to be considered intermediatly methylated
if INCLUDE_NORMAL_SAMPLES:
    CUTOFF_INTERMEDIATE_VAL = len(sample_info.index) / 2
else:
    CUTOFF_INTERMEDIATE_VAL = len(cancer_samples.index) / 2


# Percent of markers that need to be intermediatly methylated in a window
CUTOFF_PCT = 0.60

# %%
analyzer = MethylationAnalyzer(
    sample_info if INCLUDE_NORMAL_SAMPLES else cancer_samples,
    meth_ref,
    METH_INTERMEDIATE_HIGH_CUTOFF,
    METH_INTERMEDIATE_LOW_CUTOFF,
    CUTOFF_PCT,
    sample_cutoff_val_low = CUTOFF_INTERMEDIATE_VAL,
    debug = DEBUG,
    optimize_for_humans=False,
)
analyzer.analyze(True)
# Out:
# IntProgress(value=0, max=9315)
# IntProgress(value=0, max=485577)

# %%
meth_ref_sorted = analyzer.sorted_reference_data

# %%
all_sample_meth_vals = meth_ref.copy()
headers_to_exclude = set(all_sample_meth_vals.columns.values.tolist())
headers_to_exclude.remove("CpG_beg")
headers_to_exclude.remove("CpG_chrm")

meth_vals = {}

if INCLUDE_NORMAL_SAMPLES:
    samples = sample_info
else:
    samples = cancer_samples
        
for row_index, sample_row in samples.iterrows():

    sample_name = sample_row["sample"]
    meth_file = sample_row["methylation_file"]

    meth = np.load(meth_file).astype(float)
    meth[meth == 255] = np.nan
    meth_vals[sample_name] = meth

methylation_values_df = pd.DataFrame(meth_vals)
all_sample_meth_vals = pd.concat(
    [
        all_sample_meth_vals.reset_index(drop=True),
        methylation_values_df.reset_index(drop=True),
    ],
    axis=1,
)


all_sample_meth_vals.dropna(subset=["CpG_beg"], inplace=True)

all_samples = all_sample_meth_vals.drop(columns=headers_to_exclude)
all_samples["chrom_num"] = all_samples["CpG_chrm"].str.extract("(\d+)")
all_samples.dropna(subset=["chrom_num"], inplace=True)
all_samples["chrom_num"] = all_samples["chrom_num"].astype(int)
all_samples.reset_index()
# Out:
#          index CpG_chrm     CpG_beg  TCGA-EX-A1H6-01B  TCGA-C5-A7CM-01A  \
# 0            0     chr1     15864.0               NaN               NaN
# 1            1     chr1     18826.0               NaN               NaN
# 2            2     chr1     29406.0               NaN               NaN
# 3            3     chr1     29424.0               NaN               NaN
# 4            4     chr1     29434.0               NaN               NaN
# ...        ...      ...         ...               ...               ...
# 473873  473873    chr22  50783822.0               NaN               NaN
# 473874  473874    chr22  50784090.0               NaN               NaN
# 473875  473875    chr22  50784300.0               NaN               NaN
# 473876  473876    chr22  50784914.0               NaN               NaN
# 473877  473877    chr22  50787132.0               NaN               NaN
#
#         TCGA-C5-A2M1-01A  TCGA-LP-A5U2-01A  TCGA-EK-A3GK-01A  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 473873               NaN               NaN               NaN
# 473874               NaN               NaN               NaN
# 473875               NaN               NaN               NaN
# 473876               NaN               NaN               NaN
# 473877               NaN               NaN               NaN
#
#         TCGA-Q1-A73P-01A  TCGA-UC-A7PI-01A  ...  TCGA-EW-A1P1-01A  \
# 0                    NaN               NaN  ...               NaN
# 1                    NaN               NaN  ...               NaN
# 2                    NaN               NaN  ...               NaN
# 3                    NaN               NaN  ...               NaN
# 4                    NaN               NaN  ...               NaN
# ...                  ...               ...  ...               ...
# 473873               NaN               NaN  ...               NaN
# 473874               NaN               NaN  ...               NaN
# 473875               NaN               NaN  ...               NaN
# 473876               NaN               NaN  ...               NaN
# 473877               NaN               NaN  ...               NaN
#
#         TCGA-OL-A66L-01A  TCGA-AR-A0TR-01A  TCGA-BH-A0HA-01A  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 473873               NaN               NaN               NaN
# 473874               NaN               NaN               NaN
# 473875               NaN               NaN               NaN
# 473876               NaN               NaN               NaN
# 473877               NaN               NaN               NaN
#
#         TCGA-BH-A1ES-06A  TCGA-E2-A15J-01A  TCGA-B6-A40C-01A  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 473873               NaN               NaN               NaN
# 473874               NaN               NaN               NaN
# 473875               NaN               NaN               NaN
# 473876               NaN               NaN               NaN
# 473877               NaN               NaN               NaN
#
#         TCGA-E9-A1QZ-01A  TCGA-S3-AA10-01A  chrom_num
# 0                    NaN               NaN          1
# 1                    NaN               NaN          1
# 2                    NaN               NaN          1
# 3                    NaN               NaN          1
# 4                    NaN               NaN          1
# ...                  ...               ...        ...
# 473873               NaN               NaN         22
# 473874               NaN               NaN         22
# 473875               NaN               NaN         22
# 473876               NaN               NaN         22
# 473877               NaN               NaN         22
#
# [473878 rows x 9319 columns]

# %%
all_samples
# Out:
#        CpG_chrm     CpG_beg  TCGA-EX-A1H6-01B  TCGA-C5-A7CM-01A  \
# 0          chr1     15864.0               NaN               NaN
# 1          chr1     18826.0               NaN               NaN
# 2          chr1     29406.0               NaN               NaN
# 3          chr1     29424.0               NaN               NaN
# 4          chr1     29434.0               NaN               NaN
# ...         ...         ...               ...               ...
# 473873    chr22  50783822.0               NaN               NaN
# 473874    chr22  50784090.0               NaN               NaN
# 473875    chr22  50784300.0               NaN               NaN
# 473876    chr22  50784914.0               NaN               NaN
# 473877    chr22  50787132.0               NaN               NaN
#
#         TCGA-C5-A2M1-01A  TCGA-LP-A5U2-01A  TCGA-EK-A3GK-01A  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 473873               NaN               NaN               NaN
# 473874               NaN               NaN               NaN
# 473875               NaN               NaN               NaN
# 473876               NaN               NaN               NaN
# 473877               NaN               NaN               NaN
#
#         TCGA-Q1-A73P-01A  TCGA-UC-A7PI-01A  TCGA-JX-A3Q8-01A  ...  \
# 0                    NaN               NaN               NaN  ...
# 1                    NaN               NaN               NaN  ...
# 2                    NaN               NaN               NaN  ...
# 3                    NaN               NaN               NaN  ...
# 4                    NaN               NaN               NaN  ...
# ...                  ...               ...               ...  ...
# 473873               NaN               NaN               NaN  ...
# 473874               NaN               NaN               NaN  ...
# 473875               NaN               NaN               NaN  ...
# 473876               NaN               NaN               NaN  ...
# 473877               NaN               NaN               NaN  ...
#
#         TCGA-EW-A1P1-01A  TCGA-OL-A66L-01A  TCGA-AR-A0TR-01A  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 473873               NaN               NaN               NaN
# 473874               NaN               NaN               NaN
# 473875               NaN               NaN               NaN
# 473876               NaN               NaN               NaN
# 473877               NaN               NaN               NaN
#
#         TCGA-BH-A0HA-01A  TCGA-BH-A1ES-06A  TCGA-E2-A15J-01A  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 473873               NaN               NaN               NaN
# 473874               NaN               NaN               NaN
# 473875               NaN               NaN               NaN
# 473876               NaN               NaN               NaN
# 473877               NaN               NaN               NaN
#
#         TCGA-B6-A40C-01A  TCGA-E9-A1QZ-01A  TCGA-S3-AA10-01A  chrom_num
# 0                    NaN               NaN               NaN          1
# 1                    NaN               NaN               NaN          1
# 2                    NaN               NaN               NaN          1
# 3                    NaN               NaN               NaN          1
# 4                    NaN               NaN               NaN          1
# ...                  ...               ...               ...        ...
# 473873               NaN               NaN               NaN         22
# 473874               NaN               NaN               NaN         22
# 473875               NaN               NaN               NaN         22
# 473876               NaN               NaN               NaN         22
# 473877               NaN               NaN               NaN         22
#
# [473878 rows x 9318 columns]

# %%
windows_df = analyzer.windows_df
windows_df["length"] = windows_df["CpG_end"] - windows_df["CpG_beg"]
windows_df["chrom_num"] = windows_df["CpG_chrm"].str.extract("(\d+)").astype(int)

windows_df
# Out:
#       CpG_chrm    CpG_beg    CpG_end  start_idx  end_idx  count_above_pct  \
# 0         chr1     898802     898802         76       76                1
# 1         chr1     904054     904054         83       83                1
# 2         chr1     908110     908110         88       88                1
# 3         chr1     910429     924641         93      128               15
# 4         chr1     930479     930479        142      142                1
# ...        ...        ...        ...        ...      ...              ...
# 16814     chr9  137837099  137837099     473816   473816                1
# 16815     chr9  137876462  137876462     473824   473824                1
# 16816     chr9  137877146  137919088     473826   473838                6
# 16817     chr9  138045126  138045126     473852   473852                1
# 16818     chr9  138117859  138123004     473858   473865                5
#
#        count_in_window  count_in_end_tail  length  chrom_num
# 0                    1                  0       0          1
# 1                    1                  0       0          1
# 2                    1                  0       0          1
# 3                   24                  0   14212          1
# 4                    1                  0       0          1
# ...                ...                ...     ...        ...
# 16814                1                  0       0          9
# 16815                1                  0       0          9
# 16816                8                  1   41942          9
# 16817                1                  0       0          9
# 16818                6                  0    5145          9
#
# [16819 rows x 10 columns]

# %%
import swifter

# %%
def get_percent_coverge(row):
    window_samples = all_samples[
        (all_samples["chrom_num"] == row["chrom_num"])
        & (all_samples["CpG_beg"] >= row["CpG_beg"])
        & (all_samples["CpG_beg"] <= row["CpG_end"])
    ]
    window_meth_vals = window_samples.drop(columns=["CpG_chrm", "chrom_num", "CpG_beg"])
    count_with_value = window_meth_vals.notnull().sum().sum()
    total_count = window_meth_vals.size
    return np.where(total_count == 0, 0, count_with_value / total_count)

# %%
windows_df["coverage_percentage"] = windows_df.swifter.apply(
    get_percent_coverge, axis=1
)
# Out:
# Pandas Apply:   0%|          | 0/16819 [00:00<?, ?it/s]

# %%
windows_df
# Out:
#       CpG_chrm    CpG_beg    CpG_end  start_idx  end_idx  count_above_pct  \
# 0         chr1     898802     898802         76       76                1
# 1         chr1     904054     904054         83       83                1
# 2         chr1     908110     908110         88       88                1
# 3         chr1     910429     924641         93      128               15
# 4         chr1     930479     930479        142      142                1
# ...        ...        ...        ...        ...      ...              ...
# 16814     chr9  137837099  137837099     473816   473816                1
# 16815     chr9  137876462  137876462     473824   473824                1
# 16816     chr9  137877146  137919088     473826   473838                6
# 16817     chr9  138045126  138045126     473852   473852                1
# 16818     chr9  138117859  138123004     473858   473865                5
#
#        count_in_window  count_in_end_tail  length  chrom_num  \
# 0                    1                  0       0          1
# 1                    1                  0       0          1
# 2                    1                  0       0          1
# 3                   24                  0   14212          1
# 4                    1                  0       0          1
# ...                ...                ...     ...        ...
# 16814                1                  0       0          9
# 16815                1                  0       0          9
# 16816                8                  1   41942          9
# 16817                1                  0       0          9
# 16818                6                  0    5145          9
#
#       coverage_percentage
# 0                     1.0
# 1                     1.0
# 2                     1.0
# 3      0.9721059223474683
# 4                     1.0
# ...                   ...
# 16814                 1.0
# 16815                 1.0
# 16816  0.7524753292869235
# 16817                 1.0
# 16818  0.9492753623188406
#
# [16819 rows x 11 columns]

# %%
zho_common_pmds_df
# Out:
#      chrom      start        end   length
# 0     chr1          0     200000   200000
# 1     chr1     500000     700000   200000
# 2     chr1    2800000    3400000   600000
# 3     chr1    3500000    3600000   100000
# 4     chr1    3900000    5800000  1900000
# ...    ...        ...        ...      ...
# 1989  chr9  131000000  131100000   100000
# 1990  chr9  132100000  132200000   100000
# 1991  chr9  133600000  133700000   100000
# 1992  chr9  134500000  135800000  1300000
# 1993  chr9  137900000  138300000   400000
#
# [1994 rows x 4 columns]

# %%
feather.write_feather(meth_ref_sorted, "shared_data/meth_ref_sorted.feather" if INCLUDE_NORMAL_SAMPLES else "shared_data/meth_ref_sorted.cancer.feather")

# %%
feather.write_feather(all_samples, "shared_data/all_samples.feather" if INCLUDE_NORMAL_SAMPLES else "shared_data/all_samples.cancer.feather")

# %%
windows_df["coverage_percentage"] = windows_df["coverage_percentage"].astype(str)

# %%
feather.write_feather(windows_df, "shared_data/windows_df.feather" if INCLUDE_NORMAL_SAMPLES else "shared_data/windows_df.cancer.feather")

# %%
windows_df["coverage_percentage"] = windows_df["coverage_percentage"].astype(float)

# %%
feather.write_feather(zho_common_pmds_df, "shared_data/zho_common_pmds_df.feather")

# %%
LENGTH_CUTTOFF = 1000
COUNT_CUTTOFF = 50
COVERAGE_CUTOFF = .75

# %%
windows_to_analyze = windows_df[
    (windows_df["length"] > LENGTH_CUTTOFF)
    & (windows_df["count_in_window"] > COUNT_CUTTOFF)
    & (windows_df["coverage_percentage"] > COVERAGE_CUTOFF)
]

# %%
windows_to_analyze.sort_values(
    by=["chrom_num", "CpG_beg"], ascending=True, inplace=True
)
windows_to_analyze.reset_index(inplace=True)
# Out:
# /tmp/ipykernel_1325519/2467316696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   windows_to_analyze.sort_values(

# %%
windows_to_analyze
# Out:
#     index CpG_chrm    CpG_beg    CpG_end  start_idx  end_idx  count_above_pct  \
# 0    1169     chr1  118980013  119632249      27789    27962               42
# 1    9600     chr2   44929502   45170662     256085   256255               47
# 2   10121     chr2  176098854  177076134     272094   272457               79
# 3   10266     chr2  221999366  222517706     277707   277849               33
# 4   12095     chr3  147385052  149086862     324950   325187               41
# 5   13063     chr5   73176013   73451873     360610   360764               39
# 6   14334     chr6  100446636  104859853     402561   402762               36
# 7   14687     chr7    1291090    1448147     414661   414840               51
# 8   14866     chr7   27110783   27144749     420688   420833               32
# 9   14874     chr7   27185507   27364567     421030   421211               53
# 10  15132     chr7   94656359   95396898     429774   429926               44
# 11  15135     chr7   96989755   97732446     430101   430271               38
# 12   2841    chr11    1832993    1954329      73325    73510               56
# 13   2844    chr11    1998205    2135463      73613    73736               38
# 14   4472    chr12  114408606  115298340     117912   118192               59
# 15   4884    chr13   99895530   99997818     132532   132669               38
# 16   5471    chr14  104182170  104707448     150401   150730               80
# 17   5855    chr15   74131107   74345216     161421   161524               33
# 18   6034    chr15   96347368   97653003     165973   166125               44
# 19   6124    chr16     775524     843258     168184   168318               39
# 20   6138    chr16    1078013    1149835     168752   168885               38
# 21   6846    chr16   87491700   87687525     186206   186350               38
# 22   6909    chr16   88969123   89072845     187883   187996               36
# 23   7925    chr17   79090267   79658897     212659   212881               55
# 24   9153    chr19   50854987   51094751     244309   244467               43
# 25  10828    chr20   58839106   61023520     291283   291716              117
# 26  10860    chr20   63010101   63187054     292578   292705               39
# 27  10951    chr21   36542745   36990453     295315   295443               36
#
#     count_in_window  count_in_end_tail   length  chrom_num  \
# 0                67                  2   652236          1
# 1                75                  3   241160          2
# 2               126                  5   977280          2
# 3                54                  0   518340          2
# 4                66                  2  1701810          3
# 5                57                  7   275860          5
# 6                51                  8  4413217          6
# 7                82                  2   157057          7
# 8                52                  1    33966          7
# 9                75                 13   179060          7
# 10               70                  3   740539          7
# 11               59                  4   742691          7
# 12               89                  4   121336         11
# 13               56                  7   137258         11
# 14               96                  2   889734         12
# 15               52                 11   102288         13
# 16              130                  3   525278         14
# 17               51                  3   214109         15
# 18               63                 10  1305635         15
# 19               59                  5    67734         16
# 20               57                  6    71822         16
# 21               60                  3   195825         16
# 22               54                  5   103722         16
# 23               87                  4   568630         17
# 24               70                  1   239764         19
# 25              192                  2  2184414         20
# 26               60                  4   176953         20
# 27               58                  1   447708         21
#
#     coverage_percentage
# 0              0.898576
# 1              0.954641
# 2              0.917738
# 3              0.969795
# 4              0.890606
# 5              0.912059
# 6              0.836262
# 7              0.893054
# 8              0.952150
# 9              0.933422
# 10             0.938478
# 11             0.904711
# 12             0.889037
# 13             0.855881
# 14             0.938949
# 15             0.931432
# 16             0.814404
# 17             0.945881
# 18             0.912788
# 19             0.870703
# 20             0.902542
# 21             0.847273
# 22             0.926614
# 23             0.857433
# 24             0.885233
# 25             0.913785
# 26             0.895473
# 27             0.950502

# %%
helper = MethylationAnalyzerHelper(
    upper_cutoff=METH_INTERMEDIATE_HIGH_CUTOFF,
    lower_cutoff=METH_INTERMEDIATE_LOW_CUTOFF,
    dmr_percent_cutoff=CUTOFF_PCT,
    sample_cutoff_val_low=CUTOFF_INTERMEDIATE_VAL,
    debug=DEBUG,
    optimize_for_humans=False,
)

# %%
import collections

# %%
windows_to_analyze
# Out:
#     index CpG_chrm    CpG_beg    CpG_end  start_idx  end_idx  count_above_pct  \
# 0    1169     chr1  118980013  119632249      27789    27962               42
# 1    9600     chr2   44929502   45170662     256085   256255               47
# 2   10121     chr2  176098854  177076134     272094   272457               79
# 3   10266     chr2  221999366  222517706     277707   277849               33
# 4   12095     chr3  147385052  149086862     324950   325187               41
# 5   13063     chr5   73176013   73451873     360610   360764               39
# 6   14334     chr6  100446636  104859853     402561   402762               36
# 7   14687     chr7    1291090    1448147     414661   414840               51
# 8   14866     chr7   27110783   27144749     420688   420833               32
# 9   14874     chr7   27185507   27364567     421030   421211               53
# 10  15132     chr7   94656359   95396898     429774   429926               44
# 11  15135     chr7   96989755   97732446     430101   430271               38
# 12   2841    chr11    1832993    1954329      73325    73510               56
# 13   2844    chr11    1998205    2135463      73613    73736               38
# 14   4472    chr12  114408606  115298340     117912   118192               59
# 15   4884    chr13   99895530   99997818     132532   132669               38
# 16   5471    chr14  104182170  104707448     150401   150730               80
# 17   5855    chr15   74131107   74345216     161421   161524               33
# 18   6034    chr15   96347368   97653003     165973   166125               44
# 19   6124    chr16     775524     843258     168184   168318               39
# 20   6138    chr16    1078013    1149835     168752   168885               38
# 21   6846    chr16   87491700   87687525     186206   186350               38
# 22   6909    chr16   88969123   89072845     187883   187996               36
# 23   7925    chr17   79090267   79658897     212659   212881               55
# 24   9153    chr19   50854987   51094751     244309   244467               43
# 25  10828    chr20   58839106   61023520     291283   291716              117
# 26  10860    chr20   63010101   63187054     292578   292705               39
# 27  10951    chr21   36542745   36990453     295315   295443               36
#
#     count_in_window  count_in_end_tail   length  chrom_num  \
# 0                67                  2   652236          1
# 1                75                  3   241160          2
# 2               126                  5   977280          2
# 3                54                  0   518340          2
# 4                66                  2  1701810          3
# 5                57                  7   275860          5
# 6                51                  8  4413217          6
# 7                82                  2   157057          7
# 8                52                  1    33966          7
# 9                75                 13   179060          7
# 10               70                  3   740539          7
# 11               59                  4   742691          7
# 12               89                  4   121336         11
# 13               56                  7   137258         11
# 14               96                  2   889734         12
# 15               52                 11   102288         13
# 16              130                  3   525278         14
# 17               51                  3   214109         15
# 18               63                 10  1305635         15
# 19               59                  5    67734         16
# 20               57                  6    71822         16
# 21               60                  3   195825         16
# 22               54                  5   103722         16
# 23               87                  4   568630         17
# 24               70                  1   239764         19
# 25              192                  2  2184414         20
# 26               60                  4   176953         20
# 27               58                  1   447708         21
#
#     coverage_percentage
# 0              0.898576
# 1              0.954641
# 2              0.917738
# 3              0.969795
# 4              0.890606
# 5              0.912059
# 6              0.836262
# 7              0.893054
# 8              0.952150
# 9              0.933422
# 10             0.938478
# 11             0.904711
# 12             0.889037
# 13             0.855881
# 14             0.938949
# 15             0.931432
# 16             0.814404
# 17             0.945881
# 18             0.912788
# 19             0.870703
# 20             0.902542
# 21             0.847273
# 22             0.926614
# 23             0.857433
# 24             0.885233
# 25             0.913785
# 26             0.895473
# 27             0.950502

# %%
def populate_region_stats(meth_windows):
    meth_windows["next_start"] = meth_windows.groupby("chrom_num")["CpG_beg"].shift(-1)
    meth_windows["dist_to_next"] = meth_windows["next_start"] - meth_windows["CpG_end"]

    if "intermediate_percent" in meth_windows.columns:
        meth_windows = meth_windows.drop(columns=["intermediate_percent"])

    progress_bar = instantiate_progress_bar(max=len(meth_windows.index))
    percentages = []
    dist_to_next = collections.OrderedDict()

    for index, window in meth_windows.iterrows():
        progress_bar.value += 1

        pmrs, percent, int_count, total_count = helper.check_percent_in_region(
            meth_ref_sorted,
            window["CpG_chrm"],
            window["CpG_beg"],
            window["CpG_end"],
        )
        percentages.append(percent)
    return pd.concat(
        [
            meth_windows.reset_index(drop=True),
            pd.DataFrame(percentages, columns=["intermediate_percent"]).reset_index(
                drop=True
            ),
        ],
        axis=1,
    )

# %%
windows_to_analyze = populate_region_stats(windows_to_analyze)
# Out:
# /tmp/ipykernel_1325519/2645450168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meth_windows["next_start"] = meth_windows.groupby("chrom_num")["CpG_beg"].shift(-1)
# /tmp/ipykernel_1325519/2645450168.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meth_windows["dist_to_next"] = meth_windows["next_start"] - meth_windows["CpG_end"]
# IntProgress(value=0, max=28)

# %%
windows_to_analyze
# Out:
#     index CpG_chrm    CpG_beg    CpG_end  start_idx  end_idx  count_above_pct  \
# 0    1169     chr1  118980013  119632249      27789    27962               42
# 1    9600     chr2   44929502   45170662     256085   256255               47
# 2   10121     chr2  176098854  177076134     272094   272457               79
# 3   10266     chr2  221999366  222517706     277707   277849               33
# 4   12095     chr3  147385052  149086862     324950   325187               41
# 5   13063     chr5   73176013   73451873     360610   360764               39
# 6   14334     chr6  100446636  104859853     402561   402762               36
# 7   14687     chr7    1291090    1448147     414661   414840               51
# 8   14866     chr7   27110783   27144749     420688   420833               32
# 9   14874     chr7   27185507   27364567     421030   421211               53
# 10  15132     chr7   94656359   95396898     429774   429926               44
# 11  15135     chr7   96989755   97732446     430101   430271               38
# 12   2841    chr11    1832993    1954329      73325    73510               56
# 13   2844    chr11    1998205    2135463      73613    73736               38
# 14   4472    chr12  114408606  115298340     117912   118192               59
# 15   4884    chr13   99895530   99997818     132532   132669               38
# 16   5471    chr14  104182170  104707448     150401   150730               80
# 17   5855    chr15   74131107   74345216     161421   161524               33
# 18   6034    chr15   96347368   97653003     165973   166125               44
# 19   6124    chr16     775524     843258     168184   168318               39
# 20   6138    chr16    1078013    1149835     168752   168885               38
# 21   6846    chr16   87491700   87687525     186206   186350               38
# 22   6909    chr16   88969123   89072845     187883   187996               36
# 23   7925    chr17   79090267   79658897     212659   212881               55
# 24   9153    chr19   50854987   51094751     244309   244467               43
# 25  10828    chr20   58839106   61023520     291283   291716              117
# 26  10860    chr20   63010101   63187054     292578   292705               39
# 27  10951    chr21   36542745   36990453     295315   295443               36
#
#     count_in_window  count_in_end_tail   length  chrom_num  \
# 0                67                  2   652236          1
# 1                75                  3   241160          2
# 2               126                  5   977280          2
# 3                54                  0   518340          2
# 4                66                  2  1701810          3
# 5                57                  7   275860          5
# 6                51                  8  4413217          6
# 7                82                  2   157057          7
# 8                52                  1    33966          7
# 9                75                 13   179060          7
# 10               70                  3   740539          7
# 11               59                  4   742691          7
# 12               89                  4   121336         11
# 13               56                  7   137258         11
# 14               96                  2   889734         12
# 15               52                 11   102288         13
# 16              130                  3   525278         14
# 17               51                  3   214109         15
# 18               63                 10  1305635         15
# 19               59                  5    67734         16
# 20               57                  6    71822         16
# 21               60                  3   195825         16
# 22               54                  5   103722         16
# 23               87                  4   568630         17
# 24               70                  1   239764         19
# 25              192                  2  2184414         20
# 26               60                  4   176953         20
# 27               58                  1   447708         21
#
#     coverage_percentage   next_start  dist_to_next  intermediate_percent
# 0              0.898576          NaN           NaN              0.626866
# 1              0.954641  176098854.0   130928192.0              0.626667
# 2              0.917738  221999366.0    44923232.0              0.626984
# 3              0.969795          NaN           NaN              0.611111
# 4              0.890606          NaN           NaN              0.621212
# 5              0.912059          NaN           NaN              0.684211
# 6              0.836262          NaN           NaN              0.705882
# 7              0.893054   27110783.0    25662636.0              0.621951
# 8              0.952150   27185507.0       40758.0              0.615385
# 9              0.933422   94656359.0    67291792.0              0.706667
# 10             0.938478   96989755.0     1592857.0              0.628571
# 11             0.904711          NaN           NaN              0.644068
# 12             0.889037    1998205.0       43876.0              0.629213
# 13             0.855881          NaN           NaN              0.678571
# 14             0.938949          NaN           NaN              0.614583
# 15             0.931432          NaN           NaN              0.730769
# 16             0.814404          NaN           NaN              0.615385
# 17             0.945881   96347368.0    22002152.0              0.647059
# 18             0.912788          NaN           NaN              0.698413
# 19             0.870703    1078013.0      234755.0              0.661017
# 20             0.902542   87491700.0    86341865.0              0.666667
# 21             0.847273   88969123.0     1281598.0              0.633333
# 22             0.926614          NaN           NaN              0.666667
# 23             0.857433          NaN           NaN              0.632184
# 24             0.885233          NaN           NaN              0.614286
# 25             0.913785   63010101.0     1986581.0              0.609375
# 26             0.895473          NaN           NaN              0.650000
# 27             0.950502          NaN           NaN              0.620690

# %% [markdown]
# # Sources

# %% [markdown]
# 1. Zhou, W., Dinh, H.Q., Ramjan, Z. et al. DNA methylation loss in late-replicating domains is linked to mitotic cell division. Nat Genet 50, 591–602 (2018). https://doi.org/10.1038/s41588-018-0073-4
#
# 2. Dale RK, Pedersen BS, and Quinlan AR. 2011. Pybedtools: a flexible Python library for manipulating genomic datasets and annotations. Bioinformatics 27(24):3423-3424.
#
# 3. Quinlan AR and Hall IM, 2010. BEDTools: a flexible suite of utilities for comparing genomic features. Bioinformatics 26(6):841–842.

# %% [markdown]
# # Dataset
# <pre>
# data from https://www.nature.com/articles/s41588-018-0073-4
# DNA methylation loss in late-replicating domains is linked to mitotic cell division
# incredible resource here: https://zwdzwd.github.io/pmd
# !wget https://zhouserver.research.chop.edu/GenomeAnnotation/hg38/PMD_coordinates_hg38.bed.gz
# </pre>
